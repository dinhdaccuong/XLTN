# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wf
import scipy.signal as sg
import math

def funtion(x_max,n,F,Fs):
    tmp=[]
    for i in range(len(n)):
        tmp.append(x_max*math.sin(2*3.14*n[i]*F/Fs))
    return tmp
def funtion1(x,m,V):
    y=[]
    for i in range(len(x)):
        y.append((V*np.log(1+m*abs(x[i]/V))/np.log(1+m)*np.sign(x[i])))
    return y
x_max=5.0
F=10
Fs=100
n=np.arange(1,40,0.1)
x=funtion(x_max,n,F,Fs)
plt.subplot(2,1,1)
plt.plot(n,x)
y=funtion1(x,255,max(x))
plt.subplot(2,1,2)
plt.plot(n,y)
plt.show()
