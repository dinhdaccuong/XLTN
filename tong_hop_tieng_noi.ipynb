# %%
import numpy as np
import scipy.io.wavfile as wf
from scipy.io.wavfile import read
from scipy.io.wavfile import write
import matplotlib as mpl
import matplotlib.pyplot as plt
import wave
import scipy

# %%
ta_rate, ta_data = read("/home/cuong/XLTN/WAV/ta.wav")
am_rate, am_data = read("/home/cuong/XLTN/WAV/am.wav")

# %%
plt.plot(ta_data)

# %%
plt.plot(am_data)

# %%
ta_data = np.array(ta_data[0:1500])
ta_data = ta_data + 1000
am_data = np.array(am_data[2000:len(am_data)])

# %%
a = np.append(ta_data, am_data)

# %%
plt.plot(a)

# %%
write("/home/cuong/XLTN/WAV/ta_am.wav", ta_rate, a)

# %%
len(ta_data)
# Out:
# 1500
